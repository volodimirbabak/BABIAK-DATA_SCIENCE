# %% [markdown]
# # Лабораторна робота №1
# ## Тема: Підготовка робочого середовища та ознайомлення з Jupyter Notebook
# **Мета:** Ознайомитись із базовими можливостями Jupyter Notebook і Python.

# %%
name = input("Введіть своє ім’я: ")
print(f"Hello, {name}!")
# Out:
# Введіть своє ім’я:  Володимир
# Hello, Володимир!

# %%
import numpy as np

data = np.random.rand(10)
print("Масив:", data)
print("Середнє значення:", np.mean(data))
# Out:
# Масив: [0.13925478 0.75721897 0.46410674 0.13934712 0.78225464 0.26096139
#  0.65859211 0.605254   0.04331129 0.472205  ]
# Середнє значення: 0.4322506040004298
